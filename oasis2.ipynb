# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('chidubem.csv')

df.head(100)
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545  4/30/2022                     Cancelled
# 1       1  171-9198151-1101146   5/1/2022  Shipped - Delivered to Buyer
# 2       2  404-0687676-7273146   5/3/2022                       Shipped
# 3       3  403-9615377-8133951   5/5/2022                     Cancelled
# 4       4  407-1069790-7240320  5/13/2022                       Shipped
# ..    ...                  ...        ...                           ...
# 95     95  405-9112089-3379536  10/2/2022                     Cancelled
# 96     96  408-6357132-2310703  10/3/2022                       Shipped
# 97     97  406-5334922-9670748  10/4/2022                       Shipped
# 98     98  402-8519791-3706738  1/30/2023                       Shipped
# 99     99  408-1830318-0357940   2/5/2023                       Shipped
#
#    Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
df.shape
# Out:
# (100, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               100 non-null    int64
#  1   Order ID            100 non-null    object
#  2   Date                100 non-null    object
#  3   Status              100 non-null    object
#  4   Fulfilment          100 non-null    object
#  5   Sales Channel       100 non-null    object
#  6   ship-service-level  100 non-null    object
#  7   Style               100 non-null    object
#  8   SKU                 100 non-null    object
#  9   Category            100 non-null    object
#  10  Size                100 non-null    object
#  11  ASIN                100 non-null    object
#  12  Courier Status      100 non-null    object
#  13  Qty                 100 non-null    int64
#  14  currency            95 non-null     object
# ...

# %%
df.describe()
# Out:
#             index         Qty       Amount  ship-postal-code  Column1
# count  100.000000  100.000000    95.000000        100.000000      0.0
# mean    49.500000    0.910000   620.113579     481518.440000      NaN
# std     29.011492    0.287623   236.814343     188095.162249      NaN
# min      0.000000    0.000000   295.000000     110036.000000      NaN
# 25%     24.750000    1.000000   402.500000     390018.750000      NaN
# 50%     49.500000    1.000000   582.000000     500067.000000      NaN
# 75%     74.250000    1.000000   756.165000     600041.000000      NaN
# max     99.000000    1.000000  1281.000000     834004.000000      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#barplot
res = sns.barplot(x="index", y="Date", data=df,palette = "tab10")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #barplot
# ----> 2 res = sns.barplot(x="index", y="Date", data=df,palette = "tab10")
#       4 # Show the plot
#       5 plt.show()
#
# NameError: name 'sns' is not defined
