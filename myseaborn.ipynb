# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("mtcars.csv")

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.shape
# Out:
# (32, 12)

# %%
#barplot
res = sns.barplot(x="cyl", y="mpg", data=df,palette = "tab10")

# Show the plot
plt.show()

# %%
#countplot
# Vertical countplots
sns.countplot(x = 'cyl', data = df, palette ="rocket" )
# Out:
# <Axes: xlabel='cyl', ylabel='count'>

# %%
#Horizontal countplots
sns.countplot(y = "gear", data = df, palette ="rocket")
# Out:
# <Axes: xlabel='count', ylabel='gear'>

# %%
#group countplotl
#'hue' is used to visualize the data of different categories in one plot. 'palette' is used to change the colour of the plot.
# arr = arr.astype(int) 
# sns.countplot(x = 'gear', hue ='cyl', data = df ,palette ="Set2")
#

# %%
#distributionplot is use for continues data
sns.displot(df.mpg, bins = 4, color = 'g')
# Out:
# C:\Users\hp\Downloads\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df2 = df.drop(df.columns[0], axis=1)

# %%
df2.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
# heatmap in Seaborn is a data visualization tool used to represent the magnitude of values in a matrix or 2D dataset using color.
#It is particularly useful for identifying patterns, correlations, and distributions within the data.
sns.heatmap(df2.corr(), cbar = True, linewidths =0.5)
# Out:
# <Axes: >

# %%
# df3 = pd.read_csv('iris.csv')

# %%
# df3

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris, hue = 'species', size ='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(iris)
# Out:
# C:\Users\hp\Downloads\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(iris ,height =1.5, hue = 'species', palette ='Set1')
# Out:
# C:\Users\hp\Downloads\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# to show linear relatioship
sns.lmplot(x = 'petal_length', y = 'petal_width', data = iris )
# Out:
# C:\Users\hp\Downloads\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
